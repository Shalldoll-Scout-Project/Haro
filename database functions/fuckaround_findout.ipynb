# %% [markdown]
# # This notebook exists because I need to experiment around with the json product data and actually find out what's going on with it.

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the json
df = pd.read_json('../web_scraping_scripts/hlj/outputs_and_logs/hlj_products_info.json')
df.head()
# Out:
#                                                 link  stock_status  \
# 0  /1-144-scale-hg-mighty-strike-freedom-gundam-g...   May Release
# 1  /1-144-scale-hg-infinite-justice-gundam-type-i...  June Release
# 2  /1-144-scale-hg-agnes-giebenrath-s-gyan-strom-...  Apr. Release
# 3  /1-100-scale-mg-sinanju-stein-narrative-ver-ve...  June Release
# 4  /1-100-scale-mg-narrative-gundam-c-packs-ver-k...  Apr. Release
#
#                                                 name  price  \
# 0  1/144 HG Mighty Strike Freedom Gundam (Gundam ...   2700
# 1  1/144 HG Infinite Justice Gundam Type II (Gund...   2800
# 2  1/144 HG Agnes Giebenrath's Gyan Strom (Gundam...   2900
# 3    1/100 MG Sinanju Stein (Narrative Ver.) Ver. Ka   8000
# 4          1/100 MG Narrative Gundam C-Packs Ver. Ka   7000
#
#                                          description        code  \
# 0  Description\nThis is a posable, high-grade or ...  BANH663849
# 1  Description\nThis is a posable, high-grade or ...  BANH666925
# ...

# %%
df.isna().sum()
# Out:
# link             0
# stock_status     0
# name             0
# price            0
# description      0
# code             0
# jan_code         0
# release_date     0
# category         0
# series           2
# item_type        0
# manufacturer     0
# size            19
# weight          19
# dtype: int64

# %% [markdown]
# pog, not too many missing values.
